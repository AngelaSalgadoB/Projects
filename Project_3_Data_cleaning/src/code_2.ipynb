# %%
import pandas as pd

data_output=pd.read_excel(r'/Users/angelaivonnesalgadobeltran/Documents/IronHack/Projects/Project_3_Data/data_output_30.xlsx')

# %%
data_output
# Out:
#        Unnamed: 0           timestamp     company  \
# 0               0   6/7/2017 11:33:27      Oracle
# 1               1  6/10/2017 17:11:29        eBay
# 2               2  6/11/2017 14:53:57      Amazon
# 3               3   6/17/2017 0:23:14       Apple
# 4               4  6/20/2017 10:58:51   Microsoft
# ...           ...                 ...         ...
# 62637       62637   9/9/2018 11:52:32     google
# 62638       62638   9/13/2018 8:23:32   Microsoft
# 62639       62639  9/13/2018 14:35:59        MSFT
# 62640       62640  9/16/2018 16:10:35  Salesforce
# 62641       62641   1/29/2019 5:12:59       apple
#
#                               title  totalyearlycompensation  \
# 0                   Product Manager                 127000.0
# 1                 Software Engineer                 100000.0
# 2                   Product Manager                 310000.0
# 3      Software Engineering Manager                 372000.0
# ...

# %%
from dataclasses import replace
import numpy as np
data_output['tag'] = data_output['tag'].replace({ np.nan:'not entered'})

# %%
data_output
# Out:
#        Unnamed: 0           timestamp     company  \
# 0               0   6/7/2017 11:33:27      Oracle
# 1               1  6/10/2017 17:11:29        eBay
# 2               2  6/11/2017 14:53:57      Amazon
# 3               3   6/17/2017 0:23:14       Apple
# 4               4  6/20/2017 10:58:51   Microsoft
# ...           ...                 ...         ...
# 62637       62637   9/9/2018 11:52:32     google
# 62638       62638   9/13/2018 8:23:32   Microsoft
# 62639       62639  9/13/2018 14:35:59        MSFT
# 62640       62640  9/16/2018 16:10:35  Salesforce
# 62641       62641   1/29/2019 5:12:59       apple
#
#                               title  totalyearlycompensation  \
# 0                   Product Manager                 127000.0
# 1                 Software Engineer                 100000.0
# 2                   Product Manager                 310000.0
# 3      Software Engineering Manager                 372000.0
# ...

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62619       62619  8/15/2018 17:50:26  Microsoft  Not entered
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
# 62621       62621  8/15/2018 20:18:36     Google  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62619                      NaN      NaN                0.0             0.0
# 62620                      NaN      NaN                0.0             0.0
# 62621                      NaN      NaN                2.0             2.0
#
#                                   tag  basesalary  stockgrantvalue    bonus  \
# 62619                         ML / AI    108000.0         120000.0  25000.0
# 62620  Distributed Systems (Back-End)    107000.0           5000.0  28000.0
# 62621                     not entered    132000.0          55000.0  23000.0
#
#             gender  cityid  dmaid  rowNumber
# 62619  not entered   11527  819.0       1458
# ...

# %%
data_output = data_output.drop(data_output.index[62619])

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
# 62621       62621  8/15/2018 20:18:36     Google  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62620                      NaN      NaN                0.0             0.0
# 62621                      NaN      NaN                2.0             2.0
#
#                                   tag  basesalary  stockgrantvalue    bonus  \
# 62620  Distributed Systems (Back-End)    107000.0           5000.0  28000.0
# 62621                     not entered    132000.0          55000.0  23000.0
#
#             gender  cityid  dmaid  rowNumber
# 62620  not entered   11521  819.0       1467
# 62621  not entered    7322  807.0       1469

# %%
data_output = data_output.drop(data_output.index[62620])

# %%
data_output = data_output.drop(data_output.index[62620])

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62620                      NaN      NaN                0.0             0.0
#
#                                   tag  basesalary  stockgrantvalue    bonus  \
# 62620  Distributed Systems (Back-End)    107000.0           5000.0  28000.0
#
#             gender  cityid  dmaid  rowNumber
# 62620  not entered   11521  819.0       1467

# %%
data_output = data_output.drop(data_output.index[62620])

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62620                      NaN      NaN                0.0             0.0
#
#                                   tag  basesalary  stockgrantvalue    bonus  \
# 62620  Distributed Systems (Back-End)    107000.0           5000.0  28000.0
#
#             gender  cityid  dmaid  rowNumber
# 62620  not entered   11521  819.0       1467

# %%
data_output = data_output.drop(data_output.index[62620])

# %%
data_output.value_counts('totalyearlycompensation').isna()
# Out:
# totalyearlycompensation
# 200000.0     False
# 150000.0     False
# 250000.0     False
# 180000.0     False
# 160000.0     False
#              ...
# 792000.0     False
# 794000.0     False
# 799000.0     False
# 144500.0     False
# 4980000.0    False
# Length: 893, dtype: bool

# %%
data_output
# Out:
#        Unnamed: 0           timestamp     company  \
# 0               0   6/7/2017 11:33:27      Oracle
# 1               1  6/10/2017 17:11:29        eBay
# 2               2  6/11/2017 14:53:57      Amazon
# 3               3   6/17/2017 0:23:14       Apple
# 4               4  6/20/2017 10:58:51   Microsoft
# ...           ...                 ...         ...
# 62637       62637   9/9/2018 11:52:32     google
# 62638       62638   9/13/2018 8:23:32   Microsoft
# 62639       62639  9/13/2018 14:35:59        MSFT
# 62640       62640  9/16/2018 16:10:35  Salesforce
# 62641       62641   1/29/2019 5:12:59       apple
#
#                               title  totalyearlycompensation  \
# 0                   Product Manager                 127000.0
# 1                 Software Engineer                 100000.0
# 2                   Product Manager                 310000.0
# 3      Software Engineering Manager                 372000.0
# ...

# %%
mv=data_output.isna().sum()
mv
# Out:
# Unnamed: 0                 0
# timestamp                  0
# company                    0
# title                      0
# totalyearlycompensation    1
# location                   1
# yearsofexperience          0
# yearsatcompany             0
# tag                        0
# basesalary                 1
# stockgrantvalue            3
# bonus                      1
# gender                     0
# cityid                     0
# dmaid                      2
# rowNumber                  0
# dtype: int64

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]

# %%
data_output = data_output.drop(data_output.index[ 62620])

# %%
data_output

# %%
data_output.loc[data_output["basesalary"].isna()]

# %%
from dataclasses import replace
import numpy as np
data_output['basesalary'] = data_output['basesalary'].replace({ np.nan:'not entered'})

# %%
data_output.loc[data_output["basesalary"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, timestamp, company, title, totalyearlycompensation, location, yearsofexperience, yearsatcompany, tag, basesalary, stockgrantvalue, bonus, gender, cityid, dmaid, rowNumber]
# Index: []

# %%
data_output.loc[data_output["yearsofexperience"] == 41]  
# data_output.at[9615, 'yearsofexperience'] = 7.2
# Out:
#        Unnamed: 0           timestamp  company              title  \
# 10963       10963  9/16/2019 11:15:40  GoDaddy  Software Engineer
# 11020       11020  9/17/2019 11:08:01   Oracle  Software Engineer
#
#        totalyearlycompensation           location  yearsofexperience  \
# 10963                 155000.0        Phoenix, AZ               41.0
# 11020                 185000.0  San Francisco, CA               41.0
#
#        yearsatcompany         tag basesalary  stockgrantvalue    bonus gender  \
# 10963             5.0      DevOps   140000.0           3000.0  12000.0   Male
# 11020            11.0  Full Stack   152000.0          30000.0   3000.0   Male
#
#        cityid  dmaid  rowNumber
# 10963    7042  753.0      14902
# 11020    7419  807.0      14996

# %%
data_output.loc[data_output["yearsatcompany"] == 28]  
# data_output.at[37, 'yearsatcompany'] = 2.7
# Out:
#        Unnamed: 0            timestamp    company  \
# 28701       28701     9/3/2020 9:14:17  Microsoft
# 32872       32872  10/15/2020 17:28:33  Microsoft
#
#                               title  totalyearlycompensation     location  \
# 28701  Software Engineering Manager                 325000.0  Redmond, WA
# 32872             Software Engineer                1035000.0  Redmond, WA
#
#        yearsofexperience  yearsatcompany       tag basesalary  \
# 28701               28.0            28.0      Data   210000.0
# 32872               37.0            28.0  Security   300000.0
#
#        stockgrantvalue     bonus       gender  cityid  dmaid  rowNumber
# 28701          75000.0   40000.0         Male   11521  819.0      39468
# 32872         575000.0  160000.0  not entered   11521  819.0      45323

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62620                      NaN      NaN                0.0             0.0
#
#                                   tag basesalary  stockgrantvalue    bonus  \
# 62620  Distributed Systems (Back-End)   107000.0           5000.0  28000.0
#
#             gender  cityid  dmaid  rowNumber
# 62620  not entered   11521  819.0       1467

# %%
data_output = data_output.drop(data_output.index[62620])

# %%
data_output.loc[data_output["totalyearlycompensation"].isna()]
# Out:
#        Unnamed: 0           timestamp    company        title  \
# 62620       62620  8/15/2018 19:57:12  Microsoft  Not entered
#
#        totalyearlycompensation location  yearsofexperience  yearsatcompany  \
# 62620                      NaN      NaN                0.0             0.0
#
#                                   tag basesalary  stockgrantvalue    bonus  \
# 62620  Distributed Systems (Back-End)   107000.0           5000.0  28000.0
#
#             gender  cityid  dmaid  rowNumber
# 62620  not entered   11521  819.0       1467

# %%
data_output.loc[data_output["tag"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, timestamp, company, title, totalyearlycompensation, location, yearsofexperience, yearsatcompany, tag, basesalary, stockgrantvalue, bonus, gender, cityid, dmaid, rowNumber]
# Index: []

# %%
data_output
# Out:
#        Unnamed: 0           timestamp     company  \
# 0               0   6/7/2017 11:33:27      Oracle
# 1               1  6/10/2017 17:11:29        eBay
# 2               2  6/11/2017 14:53:57      Amazon
# 3               3   6/17/2017 0:23:14       Apple
# 4               4  6/20/2017 10:58:51   Microsoft
# ...           ...                 ...         ...
# 62637       62637   9/9/2018 11:52:32     google
# 62638       62638   9/13/2018 8:23:32   Microsoft
# 62639       62639  9/13/2018 14:35:59        MSFT
# 62640       62640  9/16/2018 16:10:35  Salesforce
# 62641       62641   1/29/2019 5:12:59       apple
#
#                               title  totalyearlycompensation  \
# 0                   Product Manager                 127000.0
# 1                 Software Engineer                 100000.0
# 2                   Product Manager                 310000.0
# 3      Software Engineering Manager                 372000.0
# ...

# %%
data_output.drop(['cityid'], axis=1, inplace=True)

# %%
data_output.drop(['dmaid'], axis=1, inplace=True)

# %%
data_output
# Out:
#        Unnamed: 0           timestamp     company  \
# 0               0   6/7/2017 11:33:27      Oracle
# 1               1  6/10/2017 17:11:29        eBay
# 2               2  6/11/2017 14:53:57      Amazon
# 3               3   6/17/2017 0:23:14       Apple
# 4               4  6/20/2017 10:58:51   Microsoft
# ...           ...                 ...         ...
# 62637       62637   9/9/2018 11:52:32     google
# 62638       62638   9/13/2018 8:23:32   Microsoft
# 62639       62639  9/13/2018 14:35:59        MSFT
# 62640       62640  9/16/2018 16:10:35  Salesforce
# 62641       62641   1/29/2019 5:12:59       apple
#
#                               title  totalyearlycompensation  \
# 0                   Product Manager                 127000.0
# 1                 Software Engineer                 100000.0
# 2                   Product Manager                 310000.0
# 3      Software Engineering Manager                 372000.0
# ...

# %%
data_output.to_excel("data_output_final.xlsx")
