# %%
from ast import Break
import re
from itertools import count
import random

fruits=["apple" , "apricot" , "araza" , "avocado" , "banana" , "blackberry", "blueberry", "cherry" , "coconut" , "cranberry" ,"date" , "dragonfruit" , "feijoa" , "fig", "grape", "raisin", "guava", "kiwi" , "lemon", "lime", "lychee" , "mango" , "melon", "watermelon", "nectarine" , "orange", "clementine" , "papaya" , "passionfruit", "peach", "pear", "plum" , "prune" , "pineapple", "pomegranate", "pomelo", "strawberry" ,"tamarind", "yuzu"]
chosen_fruit=""
chosen_fruit_letters=[]
tries=[]
blanks=[]
blank=" __ "

chosen_fruit=random.choice(fruits)


for letter in chosen_fruit:
    chosen_fruit_letters.append(letter)
    blanks.append(blank)
    

print(chosen_fruit_letters)
print(blanks)

tries=7
while 1<= tries  and tries<= 7 and blank in blanks:

    user_letter=input("Welcome to Hangman, Please choose a letter : ").lower()
    if not (re.match("^[a-z]*$", user_letter) and len(user_letter) ==1):
        print("Error! Only one letter a-z is allowed!")
        print(tries)
    else:
        print(user_letter)
        for index in range(len(chosen_fruit_letters)):
            if user_letter == chosen_fruit_letters[index]:
                print('correct')
                blanks[index]=user_letter
                print(blanks)
            
        if not user_letter in chosen_fruit_letters:
            tries-=1
            print("This letter" , user_letter, "doesnt exist, you have " , tries, "left")

            # elif not user_letter == chosen_fruit_letters[index]:
            #     tries-=1
            #     print("This letter" , user_letter, "doesnt exist, you have " , tries, "left")

if blanks == chosen_fruit_letters:
    print("YOU WIN")
else:
    print("YOU LOSE")
    print("The word was: ", chosen_fruit)




# for blank in range (len(chosen_fruit_letters)):
#     blanks.append(" __ ")
# print(blanks)
  
    
    # chosen_fruit_letters.append(random.choice(fruits))
    # if len(chosen_fruit)== 1:
    #     break



# print("number of letters", len(chosen_fruit[0]))



# for i in range (len(chosen_fruit[0])):
#     blanks.append(" __ ")
# print(blanks)
# Out:
# ['a', 'r', 'a', 'z', 'a']
# [' __ ', ' __ ', ' __ ', ' __ ', ' __ ']
# Error! Only one letter a-z is allowed!
# 7
# a
# in for
# correct
# ['a', ' __ ', ' __ ', ' __ ', ' __ ']
# in for
# in for
# correct
# ['a', ' __ ', 'a', ' __ ', ' __ ']
# in for
# in for
# correct
# ['a', ' __ ', 'a', ' __ ', 'a']
# a
# in for
# correct
# ['a', ' __ ', 'a', ' __ ', 'a']
# in for
# in for
# correct
# ['a', ' __ ', 'a', ' __ ', 'a']
# in for
# in for
# correct
# ['a', ' __ ', 'a', ' __ ', 'a']
# z
# in for
# in for
# in for
# in for
# correct
# ['a', ' __ ', 'a', 'z', 'a']
# in for
# z
# in for
# in for
# in for
# in for
# correct
# ['a', ' __ ', 'a', 'z', 'a']
# in for
# z
# in for
# in for
# in for
# in for
# correct
# ['a', ' __ ', 'a', 'z', 'a']
# in for
# Error! Only one letter a-z is allowed!
# 7
# Error! Only one letter a-z is allowed!
# 7
